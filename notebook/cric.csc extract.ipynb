# %%
import pickle
import pandas as pd
import numpy as np

# %%
output = pd.read_pickle('dataset_level2.pkl')

# %%
output
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2    Australia    Sri Lanka   0.1     0                0      NaN
# 1           2    Australia    Sri Lanka   0.2     0                0      NaN
# 2           2    Australia    Sri Lanka   0.3     1                0      NaN
# 3           2    Australia    Sri Lanka   0.4     2                0      NaN
# 4           2    Australia    Sri Lanka   0.5     0                0      NaN
# ..        ...          ...          ...   ...   ...              ...      ...
# 121       964    Sri Lanka    Australia  19.3     1                0  Colombo
# 122       964    Sri Lanka    Australia  19.4     0                0  Colombo
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva  Colombo
# 124       964    Sri Lanka    Australia  19.6     2                0  Colombo
# 125       964    Sri Lanka    Australia  19.7     1                0  Colombo
#
#                         venue
# 0    Melbourne Cricket Ground
# 1    Melbourne Cricket Ground
# 2    Melbourne Cricket Ground
# 3    Melbourne Cricket Ground
# 4    Melbourne Cricket Ground
# ..                        ...
# 121       R Premadasa Stadium
# 122       R Premadasa Stadium
# 123       R Premadasa Stadium
# 124       R Premadasa Stadium
# 125       R Premadasa Stadium
#
# [63888 rows x 8 columns]

# %%
output[output['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
x = np.where(output['city'].isnull(), output['venue'].str.split().apply(lambda x:x[0]), output['city'])

# %%
output['city'] = x

# %%
output.city.unique()
# Out:
# array(['Melbourne', 'Victoria', 'Adelaide', 'Napier', 'Mount Maunganui',
#        'Auckland', 'Southampton', 'Taunton', 'Cardiff',
#        'Chester-le-Street', 'Kanpur', 'Nagpur', 'Bangalore', 'Lauderhill',
#        'Dubai', 'Abu Dhabi', 'Sydney', 'Hobart', 'Wellington', 'Hamilton',
#        'Bloemfontein', 'Potchefstroom', 'Barbados', 'Trinidad', 'Colombo',
#        'St Kitts', 'Jamaica', 'Nelson', 'Ranchi', 'Birmingham',
#        'Manchester', 'Bristol', 'Delhi', 'Rajkot', 'Thiruvananthapuram',
#        'Lahore', 'Johannesburg', 'Centurion', 'Cape Town', 'Cuttack',
#        'Indore', 'Mumbai', 'Dhaka', 'Sylhet', 'Karachi', 'Harare',
#        'Carrara', 'Brisbane', 'Dehradun', 'Kolkata', 'Lucknow', 'Chennai',
#        'Gros Islet', 'Basseterre', 'Visakhapatnam', 'Bengaluru',
#        'Canberra', 'Perth', 'East London', 'Durban', 'Port Elizabeth',
#        'Chandigarh', 'Hyderabad', 'Christchurch', 'Providence', 'Kandy',
#        'Chattogram', 'Pune', 'Paarl', 'London', 'Nairobi', 'Nottingham',
#        'King City', 'Guyana', 'St Lucia', 'Antigua', 'Pallekele',
#        'Mirpur', 'Hambantota', 'Ahmedabad', 'St Vincent', 'Sharjah',
#        'Chittagong', 'Dominica', 'Dharmasala', 'Dharamsala'], dtype=object)

# %%
output.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
output.drop(columns=['venue'],inplace=True)

# %%
output
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# 122    Colombo
# 123    Colombo
# 124    Colombo
# 125    Colombo
#
# [63888 rows x 7 columns]

# %%
total_df = output.groupby('match_id').sum()['runs'].reset_index()
output = output.merge(total_df,on='match_id')

# %%
output
# Out:
#        match_id batting_team bowling_team  ball  runs_x player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1       0                0
# 1             2    Australia    Sri Lanka   0.2       0                0
# 2             2    Australia    Sri Lanka   0.3       1                0
# 3             2    Australia    Sri Lanka   0.4       2                0
# 4             2    Australia    Sri Lanka   0.5       0                0
# ...         ...          ...          ...   ...     ...              ...
# 63883       964    Sri Lanka    Australia  19.3       1                0
# 63884       964    Sri Lanka    Australia  19.4       0                0
# 63885       964    Sri Lanka    Australia  19.5       0      DM de Silva
# 63886       964    Sri Lanka    Australia  19.6       2                0
# 63887       964    Sri Lanka    Australia  19.7       1                0
#
#             city  runs_y
# 0      Melbourne     168
# 1      Melbourne     168
# 2      Melbourne     168
# 3      Melbourne     168
# 4      Melbourne     168
# ...          ...     ...
# 63883    Colombo     128
# 63884    Colombo     128
# 63885    Colombo     128
# 63886    Colombo     128
# 63887    Colombo     128
#
# [63888 rows x 8 columns]

# %%
output['runs_x'] = pd.to_numeric(output['runs_x'])

# %%
output.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63888 entries, 0 to 63887
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          63888 non-null  int64
#  1   batting_team      63888 non-null  object
#  2   bowling_team      63888 non-null  object
#  3   ball              63888 non-null  float64
#  4   runs_x            63888 non-null  int64
#  5   player_dismissed  63888 non-null  object
#  6   city              63888 non-null  object
#  7   runs_y            63888 non-null  int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 3.9+ MB

# %%
print(output['runs_x'].dtype)
# Out:
# int64

# %%
output['runs_x'].isnull().sum()
# Out:
# 0

# %%
output['runs_x'] = pd.to_numeric(output['runs_x'], errors='coerce')

# %%
print(output['match_id'].dtype)
# Out:
# int64

# %%
output['match_id'] = pd.to_numeric(output['match_id'], errors='coerce')

# %%
output['current_score'] = output.groupby('match_id')['runs_x'].cumsum()

# %%
output
# Out:
#        match_id batting_team bowling_team  ball  runs_x player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1       0                0
# 1             2    Australia    Sri Lanka   0.2       0                0
# 2             2    Australia    Sri Lanka   0.3       1                0
# 3             2    Australia    Sri Lanka   0.4       2                0
# 4             2    Australia    Sri Lanka   0.5       0                0
# ...         ...          ...          ...   ...     ...              ...
# 63883       964    Sri Lanka    Australia  19.3       1                0
# 63884       964    Sri Lanka    Australia  19.4       0                0
# 63885       964    Sri Lanka    Australia  19.5       0      DM de Silva
# 63886       964    Sri Lanka    Australia  19.6       2                0
# 63887       964    Sri Lanka    Australia  19.7       1                0
#
#             city  runs_y  current_score
# 0      Melbourne     168              0
# 1      Melbourne     168              0
# 2      Melbourne     168              1
# 3      Melbourne     168              3
# 4      Melbourne     168              3
# ...          ...     ...            ...
# 63883    Colombo     128            125
# 63884    Colombo     128            125
# 63885    Colombo     128            125
# 63886    Colombo     128            127
# 63887    Colombo     128            128
#
# [63888 rows x 9 columns]

# %%
output['over'] = output['ball'].apply(lambda x:str(x).split(".")[0])
output['ball_no'] = output['ball'].apply(lambda x:str(x).split(".")[1])

# %%
output['balls_bowled'] = (output['over'].astype('int')*6) + output['ball_no'].astype('int')

# %%
output['crr'] = round((output['current_score']*6)/output['balls_bowled'],2)

# %%
output['player_dismissed'] = output['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
output['player_dismissed'] = output['player_dismissed'].astype('int')
output['player_dismissed'] = output.groupby('match_id')['player_dismissed'].cumsum()
output['wickets_left'] = 10 - output['player_dismissed']

# %%
final_df = output[['match_id','batting_team','bowling_team','runs_x','current_score','balls_bowled','wickets_left','crr','city','runs_y']]

# %%
final_df
# Out:
#        match_id batting_team bowling_team  runs_x  current_score  \
# 0             2    Australia    Sri Lanka       0              0
# 1             2    Australia    Sri Lanka       0              0
# 2             2    Australia    Sri Lanka       1              1
# 3             2    Australia    Sri Lanka       2              3
# 4             2    Australia    Sri Lanka       0              3
# ...         ...          ...          ...     ...            ...
# 63883       964    Sri Lanka    Australia       1            125
# 63884       964    Sri Lanka    Australia       0            125
# 63885       964    Sri Lanka    Australia       0            125
# 63886       964    Sri Lanka    Australia       2            127
# 63887       964    Sri Lanka    Australia       1            128
#
#        balls_bowled  wickets_left   crr       city  runs_y
# 0                 1            10  0.00  Melbourne     168
# 1                 2            10  0.00  Melbourne     168
# 2                 3            10  2.00  Melbourne     168
# 3                 4            10  4.50  Melbourne     168
# 4                 5            10  3.60  Melbourne     168
# ...             ...           ...   ...        ...     ...
# 63883           117             2  6.41    Colombo     128
# 63884           118             2  6.36    Colombo     128
# 63885           119             1  6.30    Colombo     128
# 63886           120             1  6.35    Colombo     128
# 63887           121             1  6.35    Colombo     128
#
# [63888 rows x 10 columns]

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df['balls_left'] = 120 - final_df['balls_bowled']
final_df['balls_left'] = final_df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
final_df['crr'] = round((final_df['current_score']*6)/final_df['balls_bowled'],2)

# %%
final_df
# Out:
#        match_id batting_team bowling_team  runs_x  current_score  \
# 55121       822      England  New Zealand       1            187
# 53334       805    Sri Lanka  West Indies       1            111
# 28989       517    Sri Lanka  West Indies       1            189
# 13533       165      England  West Indies       4            182
# 47256       714    Australia     Pakistan       0            140
# ...         ...          ...          ...     ...            ...
# 18664       279  Afghanistan   Bangladesh       4             55
# 34471       571    Australia    Sri Lanka       0             45
# 20195       394   Bangladesh     Pakistan       1            126
# 33164       558    Australia     Pakistan       3            172
# 36459       588    Sri Lanka        India       4             89
#
#        balls_bowled  wickets_left   crr        city  runs_y  balls_left
# 55121           118             3  9.51  Manchester     191           2
# 53334            95             6  7.01      Mirpur     160          25
# 28989           116             6  9.78  Nottingham     192           4
# 13533           119             5  9.18  Basseterre     182           1
# 47256            87             8  9.66       Dubai     168          33
# ...             ...           ...   ...         ...     ...         ...
# 18664            43            10  7.67  Chattogram     138          77
# 34471            44             6  6.14    Barbados     168          76
# 20195           110             6  6.87      Lahore     141          10
# 33164           105             6  9.83    St Lucia     191          15
# 36459            60             9  8.90      Nagpur     215          60
#
# [63888 rows x 11 columns]

# %%
final_df.drop(columns=['balls_bowled'],inplace=True)

# %%
groups = final_df.groupby('match_id')

# %%
match_ids = final_df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30)['runs_x'].sum().values.tolist())

# %%
final_df['last_five'] = last_five

# %%
final_df
# Out:
#        match_id batting_team bowling_team  runs_x  current_score  \
# 55121       822      England  New Zealand       1            187
# 53334       805    Sri Lanka  West Indies       1            111
# 28989       517    Sri Lanka  West Indies       1            189
# 13533       165      England  West Indies       4            182
# 47256       714    Australia     Pakistan       0            140
# ...         ...          ...          ...     ...            ...
# 18664       279  Afghanistan   Bangladesh       4             55
# 34471       571    Australia    Sri Lanka       0             45
# 20195       394   Bangladesh     Pakistan       1            126
# 33164       558    Australia     Pakistan       3            172
# 36459       588    Sri Lanka        India       4             89
#
#        wickets_left   crr        city  runs_y  balls_left  last_five
# 55121             3  9.51  Manchester     191           2        NaN
# 53334             6  7.01      Mirpur     160          25        NaN
# 28989             6  9.78  Nottingham     192           4        NaN
# 13533             5  9.18  Basseterre     182           1        NaN
# 47256             8  9.66       Dubai     168          33        NaN
# ...             ...   ...         ...     ...         ...        ...
# 18664            10  7.67  Chattogram     138          77       50.0
# 34471             6  6.14    Barbados     168          76       49.0
# 20195             6  6.87      Lahore     141          10       49.0
# 33164             6  9.83    St Lucia     191          15        NaN
# 36459             9  8.90      Nagpur     215          60        NaN
#
# [63888 rows x 11 columns]

# %%
final_df.isnull().sum()
# Out:
# match_id             0
# batting_team         0
# bowling_team         0
# runs_x               0
# current_score        0
# wickets_left         0
# crr                  0
# city                 0
# runs_y               0
# balls_left           0
# last_five        15243
# dtype: int64

# %%
final_df.dropna(inplace=True)

# %%
final_df
# Out:
#        match_id batting_team bowling_team  runs_x  current_score  \
# 33532       563    Australia   Bangladesh       4            110
# 37544       607  New Zealand    Sri Lanka       0             32
# 14394       197     Pakistan    Australia       1             78
# 57509       866    Australia        India       0             54
# 35987       583     Pakistan    Australia       0            100
# ...         ...          ...          ...     ...            ...
# 22070       447    Sri Lanka      England       1              1
# 25822       482        India     Pakistan       1             27
# 18664       279  Afghanistan   Bangladesh       4             55
# 34471       571    Australia    Sri Lanka       0             45
# 20195       394   Bangladesh     Pakistan       1            126
#
#        wickets_left   crr          city  runs_y  balls_left  last_five
# 33532             4  6.41      Barbados     141          17       57.0
# 37544             8  6.19    Lauderhill     120          89       56.0
# 14394             6  6.00      Canberra     150          42       55.0
# 57509             9  9.53        Sydney     197          86       54.0
# 35987             6  7.50    Birmingham     162          40       53.0
# ...             ...   ...           ...     ...         ...        ...
# 22070            10  6.00   Southampton     163         119       58.0
# 25822             9  8.53  Johannesburg     157         101       54.0
# 18664            10  7.67    Chattogram     138          77       50.0
# 34471             6  6.14      Barbados     168          76       49.0
# 20195             6  6.87        Lahore     141          10       49.0
#
# [48645 rows x 11 columns]

# %%
eligible_cities = final_df['city'].value_counts()[final_df['city'].value_counts() > 600].index.tolist()
final_df = final_df[final_df['city'].isin(eligible_cities)]

# %%
eligible_cities
# Out:
# ['Colombo',
#  'Mirpur',
#  'Johannesburg',
#  'Dubai',
#  'Auckland',
#  'Cape Town',
#  'London',
#  'Pallekele',
#  'Barbados',
#  'Melbourne',
#  'Sydney',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Lauderhill',
#  'Hamilton',
#  'Centurion',
#  'Manchester',
#  'Abu Dhabi',
#  'Nottingham',
#  'Southampton',
#  'Mumbai',
#  'Mount Maunganui',
#  'Kolkata',
#  'Chittagong']

# %%
final_df.to_csv('crict20.csv', index=False)
